# %%
import pandas as pd

# %%
d=pd.read_csv('gpa_iq.csv')

# %%
d
# Out:
#     obs    gpa   iq  gender  concept
# 0     1  7.940  111       2       67
# 1     2  8.292  107       2       43
# 2     3  4.643  100       2       52
# 3     4  7.470  107       2       66
# 4     5  8.882  114       1       58
# ..  ...    ...  ...     ...      ...
# 73   85  9.000  112       1       60
# 74   86  9.500  112       1       70
# 75   87  6.057  114       2       51
# 76   88  6.057   93       1       21
# 77   89  6.938  106       2       56
#
# [78 rows x 5 columns]

# %%
x=d.drop(columns=['gender','obs'])

# %%
y=d['gender']

# %%
x
# Out:
#       gpa   iq  concept
# 0   7.940  111       67
# 1   8.292  107       43
# 2   4.643  100       52
# 3   7.470  107       66
# 4   8.882  114       58
# ..    ...  ...      ...
# 73  9.000  112       60
# 74  9.500  112       70
# 75  6.057  114       51
# 76  6.057   93       21
# 77  6.938  106       56
#
# [78 rows x 3 columns]

# %%
y
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     1
#      ..
# 73    1
# 74    1
# 75    2
# 76    1
# 77    2
# Name: gender, Length: 78, dtype: int64

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(3,activation='sigmoid',input_shape=((3,))))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 3)                 12
#
#  dense_2 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 16 (64.00 Byte)
# Trainable params: 16 (64.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(x,y,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 0s 222ms/step - loss: 0.0386 - accuracy: 0.3548 - val_loss: 0.1662 - val_accuracy: 0.5625
# Epoch 2/10
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0239 - accuracy: 0.3548 - val_loss: 0.1584 - val_accuracy: 0.5625
# Epoch 3/10
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0075 - accuracy: 0.3548 - val_loss: 0.1510 - val_accuracy: 0.5625
# Epoch 4/10
# 2/2 [==============================] - 0s 33ms/step - loss: -0.0048 - accuracy: 0.3548 - val_loss: 0.1435 - val_accuracy: 0.5625
# Epoch 5/10
# 2/2 [==============================] - 0s 32ms/step - loss: -0.0203 - accuracy: 0.3548 - val_loss: 0.1362 - val_accuracy: 0.5625
# Epoch 6/10
# 2/2 [==============================] - 0s 50ms/step - loss: -0.0353 - accuracy: 0.3548 - val_loss: 0.1288 - val_accuracy: 0.5625
# Epoch 7/10
# 2/2 [==============================] - 0s 32ms/step - loss: -0.0526 - accuracy: 0.3548 - val_loss: 0.1214 - val_accuracy: 0.5625
# Epoch 8/10
# 2/2 [==============================] - 0s 51ms/step - loss: -0.0673 - accuracy: 0.3548 - val_loss: 0.1135 - val_accuracy: 0.5625
# Epoch 9/10
# 2/2 [==============================] - 0s 33ms/step - loss: -0.0860 - accuracy: 0.3548 - val_loss: 0.1053 - val_accuracy: 0.5625
# Epoch 10/10
# 2/2 [==============================] - 0s 31ms/step - loss: -0.1048 - accuracy: 0.3548 - val_loss: 0.0964 - val_accuracy: 0.5625
